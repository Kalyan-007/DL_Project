# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D,Dropout,Flatten

# %%
import numpy as np
import pandas as pd
import sklearn.preprocessing as prep

# %%
from pathlib import Path
input_dir = Path.cwd()/"dataset/asl_alphabet_train"
IMAGE_FILES = list(input_dir.rglob("*.jpg"))

# %%
IMAGE_FILES[0]
# Out:
# WindowsPath('d:/DL_Project/dataset/asl_alphabet_train/asl_alphabet_train/A/A1.jpg')

# %%
import random
IMAGE_FILES_S = random.sample(IMAGE_FILES,len(IMAGE_FILES))

# %%
input_dir = Path.cwd()/"dataset/asl_alphabet_test"
IMAGE_FILES_TEST = list(input_dir.rglob("*.jpg"))

# %%
import cv2
res = []
for file in IMAGE_FILES_S:
    res.append((list(cv2.imread(file))))
res = np.array(res)

# %%
res
# Out:
# array([[[[253,   2,   0],
#          [253,   3,   0],
#          [246,   0,   3],
#          ...,
#          [245,   1,  11],
#          [246,   2,   2],
#          [243,   1,   0]],
#
#         [[255,   6,   2],
#          [231,   0,   0],
#          [211,  10,  14],
#          ...,
#          [189,   1,  12],
#          [211,   6,   8],
#          [220,   7,   2]],
#
#         [[239,   0,   2],
#          [209,  11,  15],
#          [199,  89,  93],
#          ...,
#          [255, 197, 207],
#          [255, 204, 207],
#          [167,  11,  11]],
#
#         ...,
#
#         [[250,   0,   8],
#          [192,   0,   7],
#          [163,  87,  88],
#          ...,
#          [172, 151, 159],
#          [242, 146, 152],
#          [143,  11,  17]],
#
#         [[250,   0,   1],
#          [217,   6,   9],
#          [204,  71,  73],
#          ...,
#          [239, 145, 150],
#          [255, 137, 140],
#          [172,  12,  12]],
#
#         [[251,   1,   0],
# ...

# %%
import os

folder = './dataset/asl_alphabet_train/asl_alphabet_train/'

sub_folders = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name))]

print(sub_folders)
# Out:
# ['A', 'B', 'C', 'D', 'del', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'nothing', 'O', 'P', 'Q', 'R', 'S', 'space', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']
